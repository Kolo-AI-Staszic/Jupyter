# %% [markdown]
# # Zajęcia 2
# zajęcia I - 10.10.2019
#
# prowadzący: Kajetan Knopp (kolkoaistaszic@gmail.com, kknopp@staszic.waw.pl)
#
# czwartki, 15:00

# %% [markdown]
# ## Podstawy biologiczne sztucznej inteligencji, czyli jak działają neurony

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.image as mpimg
plt.figure(figsize=(8,8))
neuron=mpimg.imread('neuron.png')
imgplot = plt.imshow(neuron)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Neurony przyjmują wiele sygnałów i sumują ich wartości, a następnie (jeśli ta suma przekroczy wartość progową) uruchamiają funkcję skokową, która wówczas produkuje sygnał. Jeśli jej nie uruchomią nie ma też sygnału.

# %%
plt.figure(figsize=(7,7))
neuron1=mpimg.imread('sygnal.png')
imgplot1 = plt.imshow(neuron1)
plt.show()

# %% [markdown]
# ### Sztuczny neuron

# %%
plt.figure(figsize=(10,10))
neuron1=mpimg.imread('aneuron.jpeg')
imgplot1 = plt.imshow(neuron1)
plt.show()

# %% [markdown]
# Funkcja skokowa
# $$y_i = f(u_i),\hspace{0.35cm} u_i=\Sigma w_{ij}x_j(t)+{w}_{i0}$$

# %% [markdown]
# $$f(u)=\{^{1,\hspace{0.25cm} u>0}_{0,\hspace{0.25cm} u\leqslant0}$$

# %%
plt.plot([-3,0,0.01,1,3],[0,0,1,1,1])

# %% [markdown]
# Funkcja liniowa
# $$f(x)=ax$$

# %%
plt.plot([1,2,3],[4,8,12])
print("a=4")
# Out:
# a=4

# %% [markdown]
# Funkcja sigmoidalna
# $$ f (x) =  \frac{\mathrm{1} }{\mathrm{1} + e^{-x}}  $$

# %%
sigmoid = lambda x: 1 / (1 + np.exp(-x))
y=linspace(-10,10,100)
plot(y,sigmoid(y),'b', label='linspace(-10,10,100)')
xlabel('X Axis')
ylabel('Y Axis')
title('Sigmoid Function')



legend(loc='lower right')

# %% [markdown]
# Tangens hiperboliczny
# $$ f (x) =  \frac{\mathrm{2} }{\mathrm{1} + e^{-2x}} -1 $$
# $$ $$
# $$f(x) = 2sigmoid(2x)-1$$

# %%
import numpy as np
import matplotlib.pyplot as plt 
  
in_array = np.linspace(-np.pi, np.pi, 12) 
out_array = np.tanh(in_array) 
  
plt.plot(in_array, out_array) 
plt.title("numpy.tanh()") 
plt.xlabel("X") 
plt.ylabel("Y") 
plt.show()

# %% [markdown]
# ReLu
# $$f(x)=max(0,x)$$

# %%
plt.plot([-10,-2,0,1,5,10],[0,0,0,1,5,10])

# %% [markdown]
# Sieci neuronowe

# %%
plt.figure(figsize=(10,10))
neuron1=mpimg.imread('network.png')
imgplot1 = plt.imshow(neuron1)
plt.show()
